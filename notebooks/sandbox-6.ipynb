# %%
import pandas as pd 
import numpy as np 
import src.fold
from tqdm import tqdm 
import requests
from src.files import *
import io
from src.fold import * 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# fold_esm('../data/ece_26_1334.fa')

# %%
fold_alphafold_make_input_file('../data/ece_26_1334.fa', '../data/ece_26_1334_alphafold.json')
# Out:
# '../data/ece_26_1334_alphafold.json'

# %%
# fold_alphafold_make_input_directory('../data/ece_26_1334.fa')
